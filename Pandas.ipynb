# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmaykhanna07/python-for-data-science/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
server_logs = {
    "Timestamp": ["10:00", "10:05", "10:10", "10:15", "10:20"],
    "Endpoint": ["/login", "/get_habits", "/login", "/update_habit", "/get_habits"],
    "Status_Code": [200, 200, 401, 500, 200],
    "Response_Time_ms": [45, 120, 30, 850, 110]
}

df = pd.DataFrame(server_logs)

df
# Out:
#   Timestamp       Endpoint  Status_Code  Response_Time_ms
# 0     10:00         /login          200                45
# 1     10:05    /get_habits          200               120
# 2     10:10         /login          401                30
# 3     10:15  /update_habit          500               850
# 4     10:20    /get_habits          200               110

# %%
response_times = df['Response_Time_ms']
print(response_times)
# Out:
# 0     45
# 1    120
# 2     30
# 3    850
# 4    110
# Name: Response_Time_ms, dtype: int64

# %%
is_crash = df['Status_Code'] == 500
crashed_requests = df[is_crash]
print(crashed_requests)
# Out:
#   Timestamp       Endpoint  Status_Code  Response_Time_ms
# 3     10:15  /update_habit          500               850

# %%
#industry standard of [4]

crashed_requests = df[df['Status_Code'] == 500]
print(crashed_requests)
# Out:
#   Timestamp       Endpoint  Status_Code  Response_Time_ms
# 3     10:15  /update_habit          500               850

# %%
endpoint_performance = df.groupby('Endpoint')['Response_Time_ms'].mean()

print("Average Response Time per Endpoint (ms):")
print(endpoint_performance)
# Out:
# Average Response Time per Endpoint (ms):
# Endpoint
# /get_habits      115.0
# /login            37.5
# /update_habit    850.0
# Name: Response_Time_ms, dtype: float64
